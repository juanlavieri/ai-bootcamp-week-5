# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = Path('./Resources/movie_scores.csv')
movies_df = pd.read_csv(csv_path)
movies_df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
# Figure out the minimum and maximum IMDB user vote count
print(movies_df["IMDB_user_vote_count"].min())
print(movies_df["IMDB_user_vote_count"].max())
# Out:
# 243
# 334164

# %%
# Create bins in which to place values based upon IMDB vote count
bins = [0, 2500, 5000, 10000, 20000, 30000, 50000, 100000, 350000]
bins = [int(b) for b in bins] # convert the list of strings to a list of integers
# Create labels for these bins
group_labels = ['0 to 2.4k', '2.5k to 4.9k', '5k to 9k', '10k to 14k', '15k to 19k', '20k to 29k', '30k to 49k', '50k to 99k']

# %%
# Slice the data and place it into bins
movies_df["IMDB_user_vote_count"] = pd.cut(movies_df["IMDB_user_vote_count"], bins, labels=group_labels)

# %%
# Place the data series into a new column inside of the DataFrame
movies_df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
# Create a GroupBy object based upon "IMDB User Votes Group"
movies_group = movies_df.groupby("IMDB_user_vote_count")


# Find how many rows fall into each bin
print(movies_group["IMDB_user_vote_count"].count())


# Create bins in which to place values based upon IMDB vote count
bins = [0, 2500, 5000, 10000, 20000, 30000, 50000, 100000, 350000]

# Create labels for these bins
group_labels = ['0 to 2.4k', '2.5k to 4.9k', '5k to 9k', '10k to 14k', '15k to 19k', '20k to 29k', '30k to 49k', '50k to 99k']

# Slice the data and place it into bins
movies_df["IMDB_user_vote_count"] = pd.cut(movies_df["IMDB_user_vote_count"], bins, labels=group_labels)
# Out:
# IMDB_user_vote_count
# 0 to 2.4k       18
# 2.5k to 4.9k    12
# 5k to 9k        16
# 10k to 14k      33
# 15k to 19k      16
# 20k to 29k      19
# 30k to 49k      16
# 50k to 99k      16
# Name: IMDB_user_vote_count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "50k to 99k"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_2_Activities/08-Stu_Movie_Ratings_Binning/Unsolved/binning_movies.ipynb Cell 7 line 9
# ...
