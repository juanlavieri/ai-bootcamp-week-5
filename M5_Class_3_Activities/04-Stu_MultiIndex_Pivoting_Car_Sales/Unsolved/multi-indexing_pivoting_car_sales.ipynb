# %%
# Import dependencies
import pandas as pd

# %%
# Read the CSV file into a DataFrame
vehicles_df = pd.read_csv('Resources/vehicles.csv')
vehicles_df.head()
# Out:
#                category  model     make  year  count
# 0  1 - Category 1 Truck  Acura  RDX 2WD  2010     15
# 1  1 - Category 1 Truck  Acura  RDX 4WD  2007      1
# 2  1 - Category 1 Truck  Acura  RDX 4WD  2008      2
# 3  1 - Category 1 Truck  Acura  RDX 4WD  2009    136
# 4  1 - Category 1 Truck  Acura  RDX 4WD  2010     30

# %%
# Show the total number of vehicles for each model and make.
grouped_vehicles = vehicles_df.groupby(['model', 'make']).size()

# Show the top 20 results.
grouped_vehicles.head(20)
# Out:
# model  make
# Acura  MDX 4WD                 2
#        RDX 2WD                 2
#        RDX 4WD                 7
#        TSX                     6
#        UNLISTED                1
# Audi   A3                      5
#        A3 Quattro              4
#        A4                      5
#        A4 Avant Quattro        2
#        A4 Cabriolet            3
#        A4 Cabriolet Quattro    1
#        A4 Quattro              6
#        A5 Cabriolet Quattro    1
#        A5 Quattro              3
#        Q5                      5
#        TT Coupe                1
#        TT Coupe Quattro        1
#        TT Roadster             2
#        TT Roadster Quattro     1
#        UNLISTED                1
# dtype: int64

# %%
# Rename the "count" column "Total"
vehicles_df = vehicles_df.rename(columns={'count': 'Total'})


# Sort the renamed pivot table on the "Total" column to show the top 20 vehicles sold by model and make. 
vehicles_df = vehicles_df.sort_values('Total', ascending=False)
vehicles_df.head(20)
# Out:
#                   category      model        make  year  Total
# 1660     P - Passenger Car     Toyota     Corolla  2010  26486
# 1320     P - Passenger Car      Honda       Civic  2009  26294
# 1651     P - Passenger Car     Toyota       Camry  2010  23258
# 1277     P - Passenger Car       Ford   Focus FWD  2009  17070
# 1348     P - Passenger Car    Hyundai     Elantra  2009  16795
# 1535     P - Passenger Car     Nissan       Versa  2009  14654
# 1672     P - Passenger Car     Toyota       Prius  2010  14180
# 1309     P - Passenger Car      Honda      Accord  2009  11958
# 1331     P - Passenger Car      Honda         Fit  2009  11828
# 253   1 - Category 1 Truck      Honda    CR-V 4WD  2009  11355
# 1178     P - Passenger Car  Chevrolet      Cobalt  2009  10485
# 1508     P - Passenger Car     Nissan      Altima  2009  10073
# 162   1 - Category 1 Truck       Ford  Escape FWD  2009   9977
# 1360     P - Passenger Car    Hyundai      Sonata  2009   9402
# 1285     P - Passenger Car       Ford  Fusion FWD  2010   8616
# 646   1 - Category 1 Truck     Toyota    RAV4 4WD  2009   8418
# 1206     P - Passenger Car  Chevrolet      Malibu  2009   8396
# 1532     P - Passenger Car     Nissan   Sentra FE  2009   8356
# 1450     P - Passenger Car      Mazda           3  2010   8205
# 1344     P - Passenger Car    Hyundai      Accent  2009   8189

# %%
# Show the total number of vehicles for each model, make, and year.
grouped_vehicles_by_year = vehicles_df.groupby(['model', 'make', 'year']).size()

# Show the top 20 results.
grouped_vehicles_by_year.head(20)
# Out:
# model  make        year
# Acura  MDX 4WD     2007    2
#        RDX 2WD     2010    2
#        RDX 4WD     2007    1
#                    2008    1
#                    2009    3
#                    2010    2
#        TSX         2007    1
#                    2008    1
#                    2009    2
#                    2010    2
#        UNLISTED    2010    1
# Audi   A3          2007    1
#                    2008    1
#                    2009    2
#                    2010    1
#        A3 Quattro  2009    3
#                    2010    1
#        A4          2008    1
#                    2009    2
#                    2010    2
# dtype: int64

# %%
# Rename the "count" column to "Total".
vehicles_df = vehicles_df.rename(columns={'count': 'Total'})


# Sort the pivot table on the "year" index and "Total" column and show the top 20 vehicles sold by the year.
vehicles_df = vehicles_df.sort_values(['year', 'Total'], ascending=[True, False])
vehicles_df.head(20)
# Out:
#                   category      model               make  year  Total
# 1533     P - Passenger Car     Nissan              Versa  2007     96
# 754   2 - Category 2 Truck  Chevrolet  Silverado C15 2WD  2007     77
# 1318     P - Passenger Car      Honda              Civic  2007     60
# 251   1 - Category 1 Truck      Honda           CR-V 4WD  2007     47
# 198   1 - Category 1 Truck       Ford  Ranger Pickup 2WD  2007     38
# 866   2 - Category 2 Truck        GMC     Sierra C15 2WD  2007     32
# 1506     P - Passenger Car     Nissan             Altima  2007     28
# 1346     P - Passenger Car    Hyundai            Elantra  2007     26
# 653   1 - Category 1 Truck     Toyota         Tacoma 2WD  2007     21
# 1236     P - Passenger Car      Dodge            Caliber  2007     21
# 644   1 - Category 1 Truck     Toyota           RAV4 4WD  2007     20
# 1342     P - Passenger Car    Hyundai             Accent  2007     20
# 248   1 - Category 1 Truck      Honda           CR-V 2WD  2007     20
# 657   1 - Category 1 Truck     Toyota         Tacoma 4WD  2007     18
# 333   1 - Category 1 Truck       Jeep        Patriot 2WD  2007     17
# 761   2 - Category 2 Truck  Chevrolet  Silverado K15 4WD  2007     16
# 1224     P - Passenger Car   Chrysler            Sebring  2007     15
# 1528     P - Passenger Car     Nissan             Sentra  2007     14
# 1176     P - Passenger Car  Chevrolet             Cobalt  2007     14
# 367   1 - Category 1 Truck        Kia       Sportage 2WD  2007     12

# %%
# Show the total number of vehicles for each category and year. 
grouped_vehicles_by_category = vehicles_df.groupby(['category', 'year']).size()

# Show the top 20 results.
grouped_vehicles_by_category.head(20)
# Out:
# category              year
# 1 - Category 1 Truck  2007     74
#                       2008    172
#                       2009    289
#                       2010    183
# 2 - Category 2 Truck  2007     24
#                       2008     37
#                       2009    169
#                       2010     62
# 3 - Category 3 Truck  2007     12
#                       2008     23
#                       2009     45
#                       2010     23
# P - Passenger Car     2007     67
#                       2008    143
#                       2009    275
#                       2010    167
# dtype: int64

# %%
# Rename the "count" column to "Total".
vehicles_df = vehicles_df.rename(columns={'count': 'Total'})


# Sort the pivot table on the on the "Total" column to show the top 20 vehicles sold by category and year.
vehicles_df = vehicles_df.sort_values('Total', ascending=False)
vehicles_df.head(20)
# Out:
#                   category      model        make  year  Total
# 1660     P - Passenger Car     Toyota     Corolla  2010  26486
# 1320     P - Passenger Car      Honda       Civic  2009  26294
# 1651     P - Passenger Car     Toyota       Camry  2010  23258
# 1277     P - Passenger Car       Ford   Focus FWD  2009  17070
# 1348     P - Passenger Car    Hyundai     Elantra  2009  16795
# 1535     P - Passenger Car     Nissan       Versa  2009  14654
# 1672     P - Passenger Car     Toyota       Prius  2010  14180
# 1309     P - Passenger Car      Honda      Accord  2009  11958
# 1331     P - Passenger Car      Honda         Fit  2009  11828
# 253   1 - Category 1 Truck      Honda    CR-V 4WD  2009  11355
# 1178     P - Passenger Car  Chevrolet      Cobalt  2009  10485
# 1508     P - Passenger Car     Nissan      Altima  2009  10073
# 162   1 - Category 1 Truck       Ford  Escape FWD  2009   9977
# 1360     P - Passenger Car    Hyundai      Sonata  2009   9402
# 1285     P - Passenger Car       Ford  Fusion FWD  2010   8616
# 646   1 - Category 1 Truck     Toyota    RAV4 4WD  2009   8418
# 1206     P - Passenger Car  Chevrolet      Malibu  2009   8396
# 1532     P - Passenger Car     Nissan   Sentra FE  2009   8356
# 1450     P - Passenger Car      Mazda           3  2010   8205
# 1344     P - Passenger Car    Hyundai      Accent  2009   8189

# %%
# Show the total number vehicles for each category, model, and year.
grouped_vehicles_by_category_model_year = vehicles_df.groupby(['category', 'model', 'year']).size()

# Show the top 20 results.
grouped_vehicles_by_category_model_year.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_3_Activities/04-Stu_MultiIndex_Pivoting_Car_Sales/Unsolved/multi-indexing_pivoting_car_sales.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_3_Activities/04-Stu_MultiIndex_Pivoting_Car_Sales/Unsolved/multi-indexing_pivoting_car_sales.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Show the total number vehicles for each category, model, and year.
# ----> <a href='vscode-notebook-cell:/Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_3_Activities/04-Stu_MultiIndex_Pivoting_Car_Sales/Unsolved/multi-indexing_pivoting_car_sales.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> grouped_vehicles_by_category_model_year = vehicles_df.groupby(['category', 'model', 'year']).size().rename_axis(['category', 'model', 'year', 'count'])
#       <a href='vscode-notebook-cell:/Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_3_Activities/04-Stu_MultiIndex_Pivoting_Car_Sales/Unsolved/multi-indexing_pivoting_car_sales.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> # Show the top 20 results.
#       <a href='vscode-notebook-cell:/Users/juanlavierigoiri/Desktop/AI-Bootcamp/Week-5/ai-bootcamp-week-5/M5_Class_3_Activities/04-Stu_MultiIndex_Pivoting_Car_Sales/Unsolved/multi-indexing_pivoting_car_sales.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> grouped_vehicles_by_category_model_year.head(20)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/series.py:4938, in Series.rename_axis(self, mapper, index, axis, copy, inplace)
#    4928 @doc(NDFrame.rename_axis)
#    4929 def rename_axis(  # type: ignore[override]
#    4930     self: Series,
#    (...)
#    4936     inplace: bool = False,
#    4937 ) -> Series | None:
# -> 4938     return super().rename_axis(
#    4939         mapper=mapper,
#    4940         index=index,
#    4941         axis=axis,
#    4942         copy=copy,
#    4943         inplace=inplace,
#    4944     )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:1232, in NDFrame.rename_axis(self, mapper, index, columns, axis, copy, inplace)
#    1228 non_mapper = is_scalar(mapper) or (
#    1229     is_list_like(mapper) and not is_dict_like(mapper)
#    1230 )
#    1231 if non_mapper:
# -> 1232     return self._set_axis_name(
#    1233         mapper, axis=axis, inplace=inplace, copy=copy
#    1234     )
#    1235 else:
#    1236     raise ValueError("Use `.rename` to alter labels with a mapper.")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:1314, in NDFrame._set_axis_name(self, name, axis, inplace, copy)
#    1262 """
#    1263 Set the name(s) of the axis.
#    1264
#    (...)
#    1311        monkey     2
#    1312 """
#    1313 axis = self._get_axis_number(axis)
# -> 1314 idx = self._get_axis(axis).set_names(name)
#    1316 inplace = validate_bool_kwarg(inplace, "inplace")
#    1317 renamed = self if inplace else self.copy(deep=copy)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:1818, in Index.set_names(self, names, level, inplace)
#    1815 else:
#    1816     idx = self._view()
# -> 1818 idx._set_names(names, level=level)
#    1819 if not inplace:
#    1820     return idx
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/multi.py:1433, in MultiIndex._set_names(self, names, level, validate)
#    1431         raise ValueError("Length of names must match length of level.")
#    1432     if level is None and len(names) != self.nlevels:
# -> 1433         raise ValueError(
#    1434             "Length of names must match number of levels in MultiIndex."
#    1435         )
#    1437 if level is None:
#    1438     level = range(self.nlevels)
#
# ValueError: Length of names must match number of levels in MultiIndex.

# %%
# Rename the "count" column to "Total"


# Sort the pivot table on the on the "Total" column to show the top 20 vehicles sold by category, model, and year.
